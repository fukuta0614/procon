# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
plt.figure(figsize=(25,25))

plt.imshow(Image.open("share1.png"), alpha=1)
plt.imshow(Image.open("share2.png"), alpha=1)

plt.show()

# %%
plt.figure(figsize=(25,25))

plt.imshow(Image.open("share1.png"), alpha=1)
plt.imshow(Image.open("share2.png"), alpha=1)
plt.imshow(Image.open("secret.png"), alpha=1)

plt.show()

# %%
282539 - 188724
# Out:
# 93815

# %%
188724 - 95256
# Out:
# 93468

# %%
187305 + 95256
# Out:
# 282561
