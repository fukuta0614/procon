# %%
import base64
import uu

with open('bin.txt') as f:
    s = f.read()


for i in range(20):
    try:
        s = base64.b64decode(s)
    except:
        pass
    print(s)


print(len(s))
# Out:
# b'
# ...

# %%
from io import BytesIO

# %%
inp = BytesIO(b'begin 666 <data>\n51DQ!1U]&94QG4#-3:4%797I74$AU\n \nend\n')
out = BytesIO()
x = uu.decode(inp, out, quiet=True)

# %%
out.getvalue()
# Out:
# b'FLAG_FeLgP3SiAWezWPHu'
